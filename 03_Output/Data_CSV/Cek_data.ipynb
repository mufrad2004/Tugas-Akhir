# %%
import pandas as pd
df = pd.read_csv("topologi_1.csv")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df
# Out:
#     topologi router_a   routing_a router_id_a  redistribute_a  \
# 0          1       R1        ospf     1.1.1.1           False
# 1          1       R1        ospf     1.1.1.1           False
# 2          1       R1        ospf     1.1.1.1           False
# 3          1       R2  ospf,eigrp     2.2.2.2            True
# 4          1       R2  ospf,eigrp     2.2.2.2            True
# 5          1       R2  ospf,eigrp     2.2.2.2            True
# 6          1       R2  ospf,eigrp     2.2.2.2            True
# 7          1       R3  ospf,eigrp     3.3.3.3            True
# 8          1       R3  ospf,eigrp     3.3.3.3            True
# 9          1       R3  ospf,eigrp     3.3.3.3            True
# 10         1       R3  ospf,eigrp     3.3.3.3            True
# 11         1       R4        ospf     4.4.4.4           False
# 12         1       R4        ospf     4.4.4.4           False
# 13         1       R4        ospf     4.4.4.4           False
# 14         1       R5  ospf,eigrp     5.5.5.5            True
# 15         1       R5  ospf,eigrp     5.5.5.5            True
# 16         1       R5  ospf,eigrp     5.5.5.5            True
# 17         1       R6       eigrp         NaN           False
# 18         1       R7  ospf,eigrp     7.7.7.7            True
# 19         1       R7  ospf,eigrp     7.7.7.7            True
# 20         1       R8       eigrp         NaN           False
# 21         1       R9  ospf,eigrp     9.9.9.9            True
# 22         1       R9  ospf,eigrp     9.9.9.9            True
# 23         1      R10       eigrp         NaN           False
# 24         1      R11       eigrp         NaN           False
# 25         1      R12       eigrp         NaN           False
#
#         interface_a          ip_a         subnet_a       auth_key_a  \
# 0   FastEthernet0/1   192.168.1.5  255.255.255.252  simple:cisco123
# 1   FastEthernet1/0   192.168.1.1  255.255.255.252  simple:cisco123
# 2   FastEthernet2/0  192.168.1.33  255.255.255.252  simple:cisco123
# 3   FastEthernet0/1   192.168.1.6  255.255.255.252  simple:cisco123
# 4   FastEthernet1/0   192.168.1.9  255.255.255.252  simple:cisco123
# 5   FastEthernet1/1  192.168.1.17  255.255.255.252  simple:cisco123
# 6   FastEthernet1/2  192.168.1.45  255.255.255.252             none
# 7   FastEthernet0/1   192.168.1.2  255.255.255.252  simple:cisco123
# 8   FastEthernet1/0  192.168.1.10  255.255.255.252  simple:cisco123
# 9   FastEthernet1/1  192.168.1.13  255.255.255.252  simple:cisco123
# 10  FastEthernet1/2  192.168.1.41  255.255.255.252             none
# 11  FastEthernet0/1  192.168.1.18  255.255.255.252  simple:cisco123
# 12  FastEthernet1/0  192.168.1.14  255.255.255.252  simple:cisco123
# 13  FastEthernet2/0  192.168.1.21  255.255.255.252  simple:cisco123
# 14  FastEthernet0/1  192.168.1.22  255.255.255.252  simple:cisco123
# 15  FastEthernet1/0  192.168.1.25  255.255.255.252             none
# 16  FastEthernet2/0  192.168.1.29  255.255.255.252  simple:cisco123
# 17  FastEthernet0/1  192.168.1.26  255.255.255.252             none
# 18  FastEthernet0/1  192.168.1.30  255.255.255.252  simple:cisco123
# 19  FastEthernet1/0  192.168.1.49  255.255.255.252             none
# 20  FastEthernet0/1  192.168.1.50  255.255.255.252             none
# 21  FastEthernet0/1  192.168.1.34  255.255.255.252  simple:cisco123
# 22  FastEthernet1/0  192.168.1.37  255.255.255.252             none
# 23  FastEthernet0/1  192.168.1.38  255.255.255.252             none
# 24  FastEthernet0/1  192.168.1.46  255.255.255.252             none
# 25  FastEthernet0/1  192.168.1.42  255.255.255.252             none
#
#    ospf_auth_a area_a  network_type_a hello_a dead_a passive_a  MTU_a  \
# 0       simple      0  Point_to_point      10     40     False   1500
# 1       simple      0  Point_to_point      10     40     False   1500
# 2       simple     20  Point_to_point      10     40     False   1500
# 3       simple      0  Point_to_point      10     40     False   1500
# 4       simple      0  Point_to_point      10     40     False   1500
# 5       simple      0  Point_to_point      10     40     False   1500
# 6         none   none            none    none   none      none   1500
# 7       simple      0  Point_to_point      10     40     False   1500
# 8       simple      0  Point_to_point      10     40     False   1500
# 9       simple      0  Point_to_point      10     40     False   1500
# 10        none   none            none    none   none      none   1500
# 11      simple      0  Point_to_point      10     40     False   1500
# 12      simple      0  Point_to_point      10     40     False   1500
# 13      simple      0  Point_to_point      10     40     False   1500
# 14      simple      0  Point_to_point      10     40     False   1500
# 15        none   none            none    none   none      none   1500
# 16      simple     10  Point_to_point      10     40     False   1500
# 17        none   none            none    none   none      none   1500
# 18      simple     10  Point_to_point      10     40     False   1500
# 19        none   none            none    none   none      none   1500
# 20        none   none            none    none   none      none   1500
# 21      simple     20  Point_to_point      10     40     False   1500
# 22        none   none            none    none   none      none   1500
# 23        none   none            none    none   none      none   1500
# 24        none   none            none    none   none      none   1500
# 25        none   none            none    none   none      none   1500
#
#    neighbor_a router_b   routing_b router_id_b  redistribute_b  \
# 0          R2       R2  ospf,eigrp     2.2.2.2            True
# 1          R3       R3  ospf,eigrp     3.3.3.3            True
# 2          R9       R9  ospf,eigrp     9.9.9.9            True
# 3          R1       R1        ospf     1.1.1.1           False
# 4          R3       R3  ospf,eigrp     3.3.3.3            True
# 5          R4       R4        ospf     4.4.4.4           False
# 6         R11      R11       eigrp         NaN           False
# 7          R1       R1        ospf     1.1.1.1           False
# 8          R2       R2  ospf,eigrp     2.2.2.2            True
# 9          R4       R4        ospf     4.4.4.4           False
# 10        R12      R12       eigrp         NaN           False
# 11         R2       R2  ospf,eigrp     2.2.2.2            True
# 12         R3       R3  ospf,eigrp     3.3.3.3            True
# 13         R5       R5  ospf,eigrp     5.5.5.5            True
# 14         R4       R4        ospf     4.4.4.4           False
# 15         R6       R6       eigrp         NaN           False
# 16         R7       R7  ospf,eigrp     7.7.7.7            True
# 17         R5       R5  ospf,eigrp     5.5.5.5            True
# 18         R5       R5  ospf,eigrp     5.5.5.5            True
# 19         R8       R8       eigrp         NaN           False
# 20         R7       R7  ospf,eigrp     7.7.7.7            True
# 21         R1       R1        ospf     1.1.1.1           False
# 22        R10      R10       eigrp         NaN           False
# 23         R9       R9  ospf,eigrp     9.9.9.9            True
# 24         R2       R2  ospf,eigrp     2.2.2.2            True
# 25         R3       R3  ospf,eigrp     3.3.3.3            True
#
#          interface_b          ip_b         subnet_b       auth_key_b  \
# 0   FastEthernet 0/1   192.168.1.6  255.255.255.252  simple:cisco123
# 1   FastEthernet 0/1   192.168.1.2  255.255.255.252  simple:cisco123
# 2   FastEthernet 0/1  192.168.1.34  255.255.255.252  simple:cisco123
# 3   FastEthernet 0/1   192.168.1.5  255.255.255.252  simple:cisco123
# 4   FastEthernet 1/0  192.168.1.10  255.255.255.252  simple:cisco123
# 5   FastEthernet 0/1  192.168.1.18  255.255.255.252  simple:cisco123
# 6   FastEthernet 0/1  192.168.1.46  255.255.255.252             none
# 7   FastEthernet 1/0   192.168.1.1  255.255.255.252  simple:cisco123
# 8   FastEthernet 1/0   192.168.1.9  255.255.255.252  simple:cisco123
# 9   FastEthernet 1/0  192.168.1.14  255.255.255.252  simple:cisco123
# 10  FastEthernet 0/1  192.168.1.42  255.255.255.252             none
# 11  FastEthernet 1/1  192.168.1.17  255.255.255.252  simple:cisco123
# 12  FastEthernet 1/1  192.168.1.13  255.255.255.252  simple:cisco123
# 13  FastEthernet 0/1  192.168.1.22  255.255.255.252  simple:cisco123
# 14  FastEthernet 2/0  192.168.1.21  255.255.255.252  simple:cisco123
# 15  FastEthernet 0/1  192.168.1.26  255.255.255.252             none
# 16  FastEthernet 0/1  192.168.1.30  255.255.255.252  simple:cisco123
# 17  FastEthernet 1/0  192.168.1.25  255.255.255.252             none
# 18  FastEthernet 2/0  192.168.1.29  255.255.255.252  simple:cisco123
# 19  FastEthernet 0/1  192.168.1.50  255.255.255.252             none
# 20  FastEthernet 1/0  192.168.1.49  255.255.255.252             none
# 21  FastEthernet 2/0  192.168.1.33  255.255.255.252  simple:cisco123
# 22  FastEthernet 0/1  192.168.1.38  255.255.255.252             none
# 23  FastEthernet 1/0  192.168.1.37  255.255.255.252             none
# 24  FastEthernet 1/2  192.168.1.45  255.255.255.252             none
# 25  FastEthernet 1/2  192.168.1.41  255.255.255.252             none
#
#    ospf_auth_b area_b  network_type_b hello_b dead_b passive_b  MTU_b  \
# 0       simple      0  Point_to_point      10     40     False   1500
# 1       simple      0  Point_to_point      10     40     False   1500
# 2       simple     20  Point_to_point      10     40     False   1500
# 3       simple      0  Point_to_point      10     40     False   1500
# 4       simple      0  Point_to_point      10     40     False   1500
# 5       simple      0  Point_to_point      10     40     False   1500
# 6         none   none            none    none   none      none   1500
# 7       simple      0  Point_to_point      10     40     False   1500
# 8       simple      0  Point_to_point      10     40     False   1500
# 9       simple      0  Point_to_point      10     40     False   1500
# 10        none   none            none    none   none      none   1500
# 11      simple      0  Point_to_point      10     40     False   1500
# 12      simple      0  Point_to_point      10     40     False   1500
# 13      simple      0  Point_to_point      10     40     False   1500
# 14      simple      0  Point_to_point      10     40     False   1500
# 15        none   none            none    none   none      none   1500
# 16      simple     10  Point_to_point      10     40     False   1500
# 17        none   none            none    none   none      none   1500
# 18      simple     10  Point_to_point      10     40     False   1500
# 19        none   none            none    none   none      none   1500
# 20        none   none            none    none   none      none   1500
# 21      simple     20  Point_to_point      10     40     False   1500
# 22        none   none            none    none   none      none   1500
# 23        none   none            none    none   none      none   1500
# 24        none   none            none    none   none      none   1500
# 25        none   none            none    none   none      none   1500
#
#    neighbor_b
# 0          R1
# 1          R1
# 2          R1
# 3          R2
# 4          R2
# 5          R2
# 6          R2
# 7          R3
# 8          R3
# 9          R3
# 10         R3
# 11         R4
# 12         R4
# 13         R4
# 14         R5
# 15         R5
# 16         R5
# 17         R6
# 18         R7
# 19         R7
# 20         R8
# 21         R9
# 22         R9
# 23        R10
# 24        R11
# 25        R12
