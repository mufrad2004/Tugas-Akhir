# %%
import pandas as pd
df = pd.read_csv("topologi_1.csv")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df
# Out:
#    topologi router_a   routing_a router_id_a  redistribute_a      interface_a  \
# 0         1       R1        ospf     1.1.1.1           False  FastEthernet0/1
# 1         1       R1        ospf     1.1.1.1           False  FastEthernet1/0
# 2         1       R1        ospf     1.1.1.1           False  FastEthernet2/0
# 3         1       R2  ospf,eigrp     2.2.2.2            True  FastEthernet1/0
# 4         1       R2  ospf,eigrp     2.2.2.2            True  FastEthernet1/1
# 5         1       R3  ospf,eigrp     3.3.3.3            True  FastEthernet1/1
# 6         1       R4        ospf     4.4.4.4           False  FastEthernet2/0
# 7         1       R5  ospf,eigrp     5.5.5.5            True  FastEthernet2/0
#
#            ip_a         subnet_a       auth_key_a ospf_auth_a  area_a  \
# 0   192.168.1.5  255.255.255.252  simple:cisco123      simple       0
# 1   192.168.1.1  255.255.255.252  simple:cisco123      simple       0
# ...
