# %%
import pandas as pd
df = pd.read_csv("GT.csv")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df[df['topologi'] == 65]
# Out:
#      topologi router_a   routing_a router_id_a  redistribute_a  \
# 512        65       R1        ospf     1.1.1.1           False
# 513        65       R1        ospf     1.1.1.1           False
# 514        65       R1        ospf     1.1.1.1           False
# 515        65       R2  ospf,eigrp     2.2.2.2            True
# 516        65       R2  ospf,eigrp     2.2.2.2            True
# 517        65       R3  ospf,eigrp     3.3.3.3            True
# 518        65       R4        ospf     4.4.4.4           False
# 519        65       R5  ospf,eigrp     5.5.5.5            True
#
#          interface_a          ip_a         subnet_a       auth_key_a  \
# 512  FastEthernet0/1   192.168.1.5  255.255.255.252  simple:cisco123
# 513  FastEthernet1/0   192.168.1.1  255.255.255.252  simple:cisco123
# 514  FastEthernet2/0  192.168.1.33  255.255.255.252  simple:cisco123
# 515  FastEthernet1/0   192.168.1.9  255.255.255.252  simple:cisco123
# ...
